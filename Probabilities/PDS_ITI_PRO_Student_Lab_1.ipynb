# %% [markdown]
# # LAB 1: Probability Concepts, Indepdenece and Random Variables
#
# In this lab you will use python to study the following topics:
#
# - How to simulate random experiment outcomes using numpy arrays.
# - How to estimate the probability of an event using the relative frequency approach.
# - Simulate independent events.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for a dataset.
# - Calculate covariance and correlation coeffecient of two random variables.

# %% [markdown]
# # First: you should run this cell

# %%
# Make all numpy available via shorter 'np' prefix
import numpy as np

# matplotlib library
import matplotlib.pyplot as plt

import pandas as pd

# %% [markdown]
# # Problem 1
#
# Use numpy to simulate the vector outcomes for repeating the following random experiments $1000$ times and use the relative frequency to compute the probability of the corresponding events:
#
# 1. **Experiment:** Flipping a fair coin, **Event:** A head occurs.
#
# Observe how changing the number of repetition affects the computed probabilities.
#
# **Hints:**
# - Use [numpy.random.randint](https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html) or [numpy.random.choice](https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html) to simulate the experiment.
# - Other useful functions [numpy.arange](https://numpy.org/doc/stable/reference/generated/numpy.arange.html), [numpy.cumsum](https://numpy.org/doc/stable/reference/generated/numpy.cumsum.html), [numpy.sum](https://numpy.org/doc/stable/reference/generated/numpy.sum.html), and [matplotlib.pyplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
repetition = [10,50,100,500,1000,5000,10000,50000,100000]
for i in  repetition :
    toss = np.random.randint(0,2 , i)
    Probability_H = np.sum(toss) / i
    print("n= " , i , " , P(e)= " , Probability_H)
    print("-----------------------------------------------------")
toss = np.random.randint(0,2 , 1000)
Probability_H = np.cumsum(toss) / np.arange(0,1000) 
plt.plot(Probability_H)
plt.axhline(y=0.5 , color='r' , linestyle = '-')
plt.grid(True)
plt.show()
# Out:
# n=  10  , P(e)=  0.3
# -----------------------------------------------------
# n=  50  , P(e)=  0.42
# -----------------------------------------------------
# n=  100  , P(e)=  0.47
# -----------------------------------------------------
# n=  500  , P(e)=  0.528
# -----------------------------------------------------
# n=  1000  , P(e)=  0.495
# -----------------------------------------------------
# n=  5000  , P(e)=  0.5098
# -----------------------------------------------------
# n=  10000  , P(e)=  0.5083
# -----------------------------------------------------
# n=  50000  , P(e)=  0.4977
# -----------------------------------------------------
# n=  100000  , P(e)=  0.49924
# -----------------------------------------------------
# C:\Users\PCCV\AppData\Local\Temp\ipykernel_7440\3262535324.py:8: RuntimeWarning: divide by zero encountered in divide
#   Probability_H = np.cumsum(toss) / np.arange(0,1000)

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.6
# -----------------------------------------
# n = 50, P(e) = 0.48
# -----------------------------------------
# n = 100, P(e) = 0.52
# -----------------------------------------
# n = 500, P(e) = 0.498
# -----------------------------------------
# n = 1000, P(e) = 0.475
# -----------------------------------------
# n = 5000, P(e) = 0.4998
# -----------------------------------------
# n = 10000, P(e) = 0.5022
# -----------------------------------------
# n = 50000, P(e) = 0.5011
# -----------------------------------------
# n = 100000, P(e) = 0.49788
# -----------------------------------------

# %% [markdown]
# 2. **Experiment:** Rolling a fair die, **Event:** Number 5 occurs.

# %%
repetition = [10,50,100,500,1000,5000,10000,50000,100000]
for i in  repetition :
    roll = np.random.randint(1,7 , i)
    Probability_five = np.sum(roll==5) / i
    print("n= " , i , " , P(e)= " , Probability_five)
    print("-----------------------------------------------------")
roll = np.random.randint(1,7 , 1000)
Probability_five = np.cumsum(roll==5) / np.arange(0,1000) 
plt.plot(Probability_five)
plt.axhline(y=0.166 , color='r' , linestyle = '-')
plt.grid(True)
plt.show()
# Out:
# n=  10  , P(e)=  0.1
# -----------------------------------------------------
# n=  50  , P(e)=  0.24
# -----------------------------------------------------
# n=  100  , P(e)=  0.26
# -----------------------------------------------------
# n=  500  , P(e)=  0.17
# -----------------------------------------------------
# n=  1000  , P(e)=  0.166
# -----------------------------------------------------
# n=  5000  , P(e)=  0.169
# -----------------------------------------------------
# n=  10000  , P(e)=  0.1669
# -----------------------------------------------------
# n=  50000  , P(e)=  0.16542
# -----------------------------------------------------
# n=  100000  , P(e)=  0.16582
# -----------------------------------------------------
# C:\Users\PCCV\AppData\Local\Temp\ipykernel_7440\1629928489.py:8: RuntimeWarning: invalid value encountered in divide
#   Probability_five = np.cumsum(roll==5) / np.arange(0,1000)

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.2
# -----------------------------------------
# n = 50, P(e) = 0.12
# -----------------------------------------
# n = 100, P(e) = 0.19
# -----------------------------------------
# n = 500, P(e) = 0.166
# -----------------------------------------
# n = 1000, P(e) = 0.151
# -----------------------------------------
# n = 5000, P(e) = 0.1648
# -----------------------------------------
# n = 10000, P(e) = 0.1663
# -----------------------------------------
# n = 50000, P(e) = 0.1661
# -----------------------------------------
# n = 100000, P(e) = 0.16817
# -----------------------------------------

# %% [markdown]
# 3. **Experiment:** Rolling a fair die, **Event:** A number greater than 3 occurs.

# %%
repetition = [10,50,100,500,1000,5000,10000,50000,100000]
for i in  repetition :
    roll = np.random.randint(1,7 , i)
    Probability_greaterthan3 = np.sum(roll>3) / i
    print("n= " , i , " , P(e)= " , Probability_greaterthan3)
    print("-----------------------------------------------------")
roll = np.random.randint(1,7 , 1000)
Probability_greaterthan3 = np.cumsum(roll>3) / np.arange(0,1000) 
plt.plot(Probability_greaterthan3)
plt.axhline(y=0.5 , color='r' , linestyle = '-')
plt.grid(True)
plt.show()
# Out:
# n=  10  , P(e)=  0.3
# -----------------------------------------------------
# n=  50  , P(e)=  0.48
# -----------------------------------------------------
# n=  100  , P(e)=  0.49
# -----------------------------------------------------
# n=  500  , P(e)=  0.516
# -----------------------------------------------------
# n=  1000  , P(e)=  0.5
# -----------------------------------------------------
# n=  5000  , P(e)=  0.507
# -----------------------------------------------------
# n=  10000  , P(e)=  0.5061
# -----------------------------------------------------
# n=  50000  , P(e)=  0.49774
# -----------------------------------------------------
# n=  100000  , P(e)=  0.50171
# -----------------------------------------------------
# C:\Users\PCCV\AppData\Local\Temp\ipykernel_7440\329093692.py:8: RuntimeWarning: divide by zero encountered in divide
#   Probability_greaterthan3 = np.cumsum(roll>3) / np.arange(0,1000)

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.6
# -----------------------------------------
# n = 50, P(e) = 0.48
# -----------------------------------------
# n = 100, P(e) = 0.44
# -----------------------------------------
# n = 500, P(e) = 0.496
# -----------------------------------------
# n = 1000, P(e) = 0.489
# -----------------------------------------
# n = 5000, P(e) = 0.5052
# -----------------------------------------
# n = 10000, P(e) = 0.4962
# -----------------------------------------
# n = 50000, P(e) = 0.49842
# -----------------------------------------
# n = 100000, P(e) = 0.49983
# -----------------------------------------

# %% [markdown]
# 4. **Experiment:** Rolling two fair dice, **Event:** Sum of two dice equal 5.

# %%
repetition = [10,50,100,500,1000,5000,10000,50000,100000]
roll = np.random.randint(1,7 , (50,2))
print(roll)
# Out:
# [[5 6]
#  [5 2]
#  [1 5]
#  [4 3]
#  [2 2]
#  [2 5]
#  [6 6]
#  [2 5]
#  [6 1]
#  [6 5]
#  [5 4]
#  [2 1]
#  [2 4]
#  [4 2]
#  [3 6]
#  [3 3]
#  [4 5]
#  [6 5]
#  [4 4]
#  [4 6]
#  [3 6]
#  [4 6]
#  [3 3]
#  [3 2]
#  [3 4]
#  [4 6]
#  [1 3]
#  [5 4]
#  [1 1]
#  [4 1]
#  [1 6]
#  [3 3]
#  [4 4]
#  [6 5]
#  [3 1]
#  [4 5]
#  [4 4]
#  [5 2]
#  [6 5]
#  [6 6]
#  [1 5]
#  [3 6]
#  [3 5]
#  [5 5]
#  [2 5]
#  [1 1]
#  [5 3]
#  [4 6]
#  [3 6]
#  [1 1]]

# %%
repetition = [10,50,100,500,1000,5000,10000,50000,100000]
for i in  repetition :
    roll = np.random.randint(1,7 , (i,2))
    Probability_sumisfive = np.sum(np.sum(roll,axis=1)==5) / i
    print("n= " , i , " , P(e)= " , Probability_sumisfive)
    print("-----------------------------------------------------")
roll = np.random.randint(1,7 , (1000,2))
Probability_sumisfive = np.cumsum(np.sum(roll,axis=1)==5) / np.arange(0,1000) 
plt.plot(Probability_sumisfive)
plt.axhline(y=0.111 , color='r' , linestyle = '-')
plt.grid(True)
plt.show()
# Out:
# n=  10  , P(e)=  0.1
# -----------------------------------------------------
# n=  50  , P(e)=  0.08
# -----------------------------------------------------
# n=  100  , P(e)=  0.18
# -----------------------------------------------------
# n=  500  , P(e)=  0.134
# -----------------------------------------------------
# n=  1000  , P(e)=  0.106
# -----------------------------------------------------
# n=  5000  , P(e)=  0.1146
# -----------------------------------------------------
# n=  10000  , P(e)=  0.1174
# -----------------------------------------------------
# n=  50000  , P(e)=  0.11088
# -----------------------------------------------------
# n=  100000  , P(e)=  0.11043
# -----------------------------------------------------
# C:\Users\PCCV\AppData\Local\Temp\ipykernel_7440\2660303909.py:8: RuntimeWarning: invalid value encountered in divide
#   Probability_sumisfive = np.cumsum(np.sum(roll,axis=1)==5) / np.arange(0,1000)

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.1
# -----------------------------------------
# n = 50, P(e) = 0.04
# -----------------------------------------
# n = 100, P(e) = 0.11
# -----------------------------------------
# n = 500, P(e) = 0.116
# -----------------------------------------
# n = 1000, P(e) = 0.112
# -----------------------------------------
# n = 5000, P(e) = 0.1134
# -----------------------------------------
# n = 10000, P(e) = 0.1056
# -----------------------------------------
# n = 50000, P(e) = 0.10812
# -----------------------------------------
# n = 100000, P(e) = 0.10955
# -----------------------------------------

# %% [markdown]
# # Problem 2
#
# Simulate the experiment of tossing $1000$ times a coin with probability of **head (coded as $1$) equal to $0.4$** and probability of **tail (coded as $0$) equal to $0.6$**. How can you check if the simulation of the experiment of been running as expected.
#
# **Hint**: Use [matplotlib.pyplot.hist¶
# ](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)

# %%
toss = np.random.choice([0,1] , 1000 , p=[0.6,0.4])
plt.hist(toss)
plt.grid()
plt.show()

# %%
#type your code here:

# %% [markdown]
# # Problem 3: Independence
#
# Use NumPy to create simulations and compute **empirical  probability** for the following outcomes. Compare the results with the **theoretical probability**.
#
# 1. Two fair coin flips produce exactly two heads

# %%
coin = np.random.choice([0,1] , (1000000,2))
all_sum = np.sum(np.sum(coin , axis=1)==2 ) / 1000000
print(all_sum)
# Out:
# 0.249178

# %%
#type your code here:

# simulate 1 million tests of two fair coin flips


# sums of all tests


# proportion of tests that produced exactly two heads
# Out:
# 0.249809

# %% [markdown]
# 2. Three fair coin flips produce exactly one head

# %%
coin = np.random.choice([0,1] , (1000000,3))
all_sum = np.sum(np.sum(coin , axis=1)==1 ) / 1000000
print(all_sum)
# Out:
# 0.375244

# %%
#type your code here:

# simulate 1 million tests of three fair coin flips


# sums of all tests


# proportion of tests that produced exactly one head
# Out:
# 0.374819

# %% [markdown]
# 3. Three biased coin flips with P(H) = 0.6 produce exactly one head

# %%
coin = np.random.choice([0,1] , (1000000,3) , p=[0.4,0.6])
all_sum = np.sum(np.sum(coin , axis=1)==1 ) / 1000000
print(all_sum)
# Out:
# 0.287903

# %%
#type your code here:


# simulate 1 million tests of three biased coin flips
# hint: use np.random.choice()


# sums of all tests


# proportion of tests that produced exactly one head
# Out:
# 0.288288

# %% [markdown]
# # Problem 4:Random Variables Statistical Tools
# Simulate Rolling a fair die $1000$ times. Then calculate the following:
#
# - Sample mean
# - Sample variance
# - Sample standard deviation
#
# Compare the results with the theoretical probability.

# %%
roll = np.random.randint(1,7 , 1000)
theo_mean = (1+2+3+4+5+6) / 6
theo_variance = np.sum(((1-theo_mean)**2 , (2-theo_mean)**2 ,(3-theo_mean)**2 , (4-theo_mean)**2 , (5-theo_mean)**2 , (6-theo_mean)**2)) / 6
theo_std = np.sqrt(theo_variance)
print("Theoritical mean = ",theo_mean)
print("Theoritical variance = " , theo_variance)
print("Theoriticial standard deviation = " , theo_std)
mean = np.mean(roll)
variance = np.var(roll)
standard_deviation = np.std(roll)
print("Sample mean = " , mean)
print("Sample variance = " , variance)
print("Sample standard deviation =" , standard_deviation)
# Out:
# Theoritical mean =  3.5
# Theoritical variance =  2.9166666666666665
# Theoriticial standard deviation =  1.707825127659933
# Sample mean =  3.543
# Sample variance =  2.918151
# Sample standard deviation = 1.708259640686977

# %%
#type your code here:
# Out:
# Sample mean: 3.463
# Sample variance: 3.005636636636637
# Sample standard deviation: 1.7336772008181445
# 3.463
# 3.005636636636637
# 1.7336772008181445

# %% [markdown]
# # Problem 5: Correlation and Covariance
#
# The CSV file includes a hourly/daily summary for Szeged, Hungary area, between 2006 and 2016. After inspecting the data:
#
# - Calculate the covariance and correlation coeffecient between temperature and apparent temperature
# - Calculate the covariance and correlation coeffecient between temperature and humidity

# %%
df = pd.read_csv('weatherHistory.csv')
temperature = df['Temperature (C)'].to_numpy().reshape(-1, 1)
apparant_temp = df['Apparent Temperature (C)'].to_numpy().reshape(-1, 1)
humidity = df['Humidity'].to_numpy().reshape(-1, 1)

# %%
plt.scatter(temperature, apparant_temp)
plt.grid()
plt.xlabel('Temperature (C)')
plt.ylabel('Apparent Temperature (C)')
# Out:
# Text(0, 0.5, 'Apparent Temperature (C)')

# %%
plt.scatter(humidity, temperature)
plt.grid()
plt.xlabel('Humidity')
plt.ylabel('Temperature (C)')
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %% [markdown]
# ## Temperature and Apparent Temperature

# %%
cov = (df['Temperature (C)'].cov(df['Apparent Temperature (C)']))
cov1 = np.cov(df['Temperature (C)'] , df['Apparent Temperature (C)'])
print("Covariance :" , cov)
print("-----------------------------------------------------------------")
print("np.cov() : \n" , cov1)
print("-------------------------------------------------------------------------------------------------------")
coef = (df['Temperature (C)'].corr(df['Apparent Temperature (C)']))
coef1 = np.corrcoef(df['Temperature (C)'] , df['Apparent Temperature (C)'])
print("Correlation Coef. : " , coef)
print("-----------------------------------------------------------------")
print("np.corrcoef() : \n" , coef1)
# Out:
# Covariance : 101.41828318854094
# -----------------------------------------------------------------
# np.cov() :
#  [[ 91.23203712 101.41828319]
#  [101.41828319 114.42254413]]
# -------------------------------------------------------------------------------------------------------
# Correlation Coef. :  0.9926285641920811
# -----------------------------------------------------------------
# np.corrcoef() :
#  [[1.         0.99262856]
#  [0.99262856 1.        ]]

# %%
#type your code here:
# Out:
# Covariance:  [[101.41828319]]
# ---------------------------------------------------
# np.cov():
#  [[ 91.23203712 101.41828319]
#  [101.41828319 114.42254413]]
# ---------------------------------------------------
# Correlation Cof:  [[0.99262856]]
# ---------------------------------------------------
# np.corrcoef():
#  [[1.         0.99262856]
#  [0.99262856 1.        ]]

# %% [markdown]
# ## Temperature and Humidity

# %%
cov = (df['Temperature (C)'].cov(df['Humidity']))
cov1 = np.cov(df['Temperature (C)'] , df['Humidity'])
print("Covariance :" , cov)
print("-----------------------------------------------------------------")
print("np.cov() : \n" , cov1)
print("-------------------------------------------------------------------------------------------------------")
coef = (df['Temperature (C)'].corr(df['Humidity']))
coef1 = np.corrcoef(df['Temperature (C)'] , df['Humidity'])
print("Correlation Coef. : " , coef)
print("-----------------------------------------------------------------")
print("np.corrcoef() : \n" , coef1)
# Out:
# Covariance : -1.1804617897851366
# -----------------------------------------------------------------
# np.cov() :
#  [[ 9.12320371e+01 -1.18046179e+00]
#  [-1.18046179e+00  3.82095917e-02]]
# -------------------------------------------------------------------------------------------------------
# Correlation Coef. :  -0.6322546750264326
# -----------------------------------------------------------------
# np.corrcoef() :
#  [[ 1.         -0.63225468]
#  [-0.63225468  1.        ]]

# %%
#type your code here:
# Out:
# Covariance:  [[-1.18046179]]
# ---------------------------------------------------
# np.cov():
#  [[ 9.12320371e+01 -1.18046179e+00]
#  [-1.18046179e+00  3.82095917e-02]]
# ---------------------------------------------------
# Correlation Cof:  [[-0.63225468]]
# ---------------------------------------------------
# np.corrcoef():
#  [[ 1.         -0.63225468]
#  [-0.63225468  1.        ]]
